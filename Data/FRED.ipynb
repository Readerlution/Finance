# %%
from pandas_datareader import data as pdr
import pandas_datareader as web
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
yf.pdr_override()

t10y2y = web.DataReader("T10Y2Y", 'fred', start= "1970-01-01")
t10y3m = web.DataReader("T10Y3M", 'fred', start= "1987-01-01")

# %%
rate_diff = pd.concat([t10y2y, t10y3m])

# %%
sp = pdr.DataReader("^KS200", start="1990-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ^KS200: No data found for this date range, symbol may be delisted

# %%
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(t10y2y, color = 'black', linewidth = 0.5, label='10Y-2Y')
ax1.plot(t10y3m, color = 'gray', linewidth = 0.5, label='10Y-3M')
ax1.axhline(y=0, color = 'r', linestyle='dashed')
ax1.set_ylabel("장단기 금리차")
ax1.legend(loc = 'upper right')

# ax2 = ax1.twinx()
# ax2.plot(np.log(sp['Close']), label='S&P500')
# ax2.set_ylabel('S&P500 지수(log)')
# ax2.legend(loc = 'upper right')

plt.show()

# %%
vix = web.DataReader("VIXCLS", 'fred', start= "1970-01-01")
gold_vix = web.DataReader("GVZCLS", 'fred', start= "1970-01-01")
oil_vix = web.DataReader("OVXCLS", 'fred', start= "1970-01-01")
rus_vix = web.DataReader("RVXCLS", 'fred', start= "1970-01-01")
nq_vix = web.DataReader("VXNCLS", 'fred', start= "1970-01-01")

# %%
vix_df = pd.concat([vix,gold_vix,oil_vix,rus_vix,nq_vix], axis=1)

# %%
vix_df
# Out:
#             VIXCLS  GVZCLS  OVXCLS  RVXCLS  VXNCLS
# DATE
# 1990-01-02   17.24     NaN     NaN     NaN     NaN
# 1990-01-03   18.19     NaN     NaN     NaN     NaN
# 1990-01-04   19.22     NaN     NaN     NaN     NaN
# 1990-01-05   20.11     NaN     NaN     NaN     NaN
# 1990-01-08   20.26     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2023-12-07   13.06   14.93   37.82   21.33   17.08
# 2023-12-08   12.35   14.14   36.24   20.26   15.94
# 2023-12-11   12.63   13.99   35.30   20.74   16.27
# 2023-12-12   12.07   12.82   36.38   19.42   15.38
# 2023-12-13   12.19   13.67   36.60   19.82   15.35
#
# [8858 rows x 5 columns]
