# %%
import numpy as np
import pandas as pd
import yfinance as yf
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import seaborn as sns

yf.pdr_override()

# %%
ticker_df = pd.read_csv("2023-07-15-WatchListScanner.csv")
ticker_df
# Out:
#     Symbol                                Description   Last  Net Chng  \
# 0      FUN  CEDAR FAIR LP DEPOSITRY UTS(REP LTD PART)  37.50     -0.25
# 1      TNL                 TRAVEL PLUS LEISURE CO COM  41.82     -1.32
# 2      RRR              RED ROCK RESORTS INC COM CL A  49.07      0.39
# 3      TPX         TEMPUR SEALY INTERNATIONAL INC COM  43.97     -0.02
# 4     FTDR                          FRONTDOOR INC COM  34.04     -0.07
# ..     ...                                        ...    ...       ...
# 195     TX                             TERNIUM SA ADR  43.79      0.07
# 196    OFG                            OFG BANCORP COM  28.26     -0.15
# 197   DOCS                      DOXIMITY INC COM CL A  35.35      0.22
# 198   SWBI            SMITH AND WESSON BRANDS INC COM  13.15     -0.18
# 199   CDMO                   AVID BIOSERVICES INC COM  13.23     -0.14
#
#     %Change  volumechange     Volume    Bid  \
# 0    -0.66%        -16.60    533,110  37.14
# 1    -3.06%         62.36    818,279  41.40
# 2    +0.80%        -25.26    275,451  48.53
# 3    -0.05%        -11.95  1,334,089  43.54
# 4    -0.21%        -57.45    391,285  33.80
# ..      ...           ...        ...    ...
# 195  +0.16%         26.53    223,717  43.55
# 196  -0.53%         -9.84    195,549  27.35
# 197  +0.63%        -58.91  1,038,728  34.51
# 198  -1.35%         -0.19    287,903  13.00
# 199  -1.05%         18.70    402,040  12.57
#
#      Return on Equity (ROE) - Current (Annual)    Ask    High     Low  \
# 0                                    1535.5000  37.86  37.730  37.300
# 1                                     689.2300  42.24  43.170  41.430
# 2                                     397.8700  49.60  49.070  48.070
# 3                                     345.6200  44.39  44.130  43.390
# 4                                     225.4000  34.28  34.180  33.760
# ..                                         ...    ...     ...     ...
# 195                                    15.7950  44.05  43.890  43.125
# 196                                    15.7460  29.87  28.695  28.140
# 197                                    12.2320  38.90  35.490  34.755
# 198                                     9.8978  13.15  13.330  12.990
# 199                                     0.3077  13.93  13.520  13.125
#
#     Market Cap
# 0      1,925 M
# 1      3,188 M
# 2      2,856 M
# 3      7,566 M
# 4      2,782 M
# ..         ...
# 195    8,596 M
# 196    1,343 M
# 197    6,885 M
# 198      606 M
# 199      830 M
#
# [200 rows x 13 columns]

# %%
tickers = ~ticker_df['Symbol'].isin(['AESI', 'NXT', 'VTS', 'CWEN/A'])
tickers = list(ticker_df[tickers]['Symbol'])

# %%
df = pdr.DataReader(list(tickers), start="2022-01-01", end="2023-01-01", period='1d')
# Out:
# [*********************100%***********************]  196 of 196 completed

# %%
df
# Out:
#            Adj Close                                                         \
#                 ACEL        ACT       AEHR       AIRC       AMBC       AMKR
# Date
# 2022-01-03     13.21  19.718229  23.389999  51.153191  16.000000  25.830570
