# %%
import numpy as np
import pandas as pd
import yfinance as yf
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import seaborn as sns

yf.pdr_override()

# %%
ticker_df = pd.read_csv("2023-07-15-WatchListScanner.csv")
ticker_df
# Out:
#     Symbol                                Description   Last  Net Chng  \
# 0      FUN  CEDAR FAIR LP DEPOSITRY UTS(REP LTD PART)  37.50     -0.25
# 1      TNL                 TRAVEL PLUS LEISURE CO COM  41.82     -1.32
# 2      RRR              RED ROCK RESORTS INC COM CL A  49.07      0.39
# 3      TPX         TEMPUR SEALY INTERNATIONAL INC COM  43.97     -0.02
# 4     FTDR                          FRONTDOOR INC COM  34.04     -0.07
# ..     ...                                        ...    ...       ...
# 195     TX                             TERNIUM SA ADR  43.79      0.07
# 196    OFG                            OFG BANCORP COM  28.26     -0.15
# 197   DOCS                      DOXIMITY INC COM CL A  35.35      0.22
# 198   SWBI            SMITH AND WESSON BRANDS INC COM  13.15     -0.18
# 199   CDMO                   AVID BIOSERVICES INC COM  13.23     -0.14
#
#     %Change  volumechange     Volume    Bid  \
# 0    -0.66%        -16.60    533,110  37.14
# ...

# %%
tickers = ticker_df['Symbol']

# %%
# fmp_key = "806b1540043a45c09f1a2f97d9a1d6e4"
# companies = Toolkit(list(ticker_df['Symbol']), api_key=fmp_key)

# %%
# companies.ratios

# %%
# historical_data = companies.get_historical_data(start="2018-01-01", end="2021-01-01")

# %%
# historical_data

# %%
# companies.ratios.collect_profitability_ratios()

# %%
df = pdr.DataReader(list(tickers), start="2022-01-01", end="2023-01-01", period='1d')
# Out:
# Failed to get ticker 'CWEN/A' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  200 of 200 completed
# 4 Failed downloads:
# ['CWEN/A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['NXT', 'AESI', 'VTS']: Exception("%ticker%: Data doesn't exist for startDate = 1577854800, endDate = 1672462800")

# %%
df
# Out:
#            Adj Close                                                   \
#                 ACEL        ACT       AEHR AESI       AIRC       AMBC
# Date
# 2020-01-02     12.50        NaN   2.070000  NaN        NaN  21.760000
# 2020-01-03     12.57        NaN   2.090000  NaN        NaN  21.730000
# 2020-01-06     12.40        NaN   1.980000  NaN        NaN  21.760000
# 2020-01-07     12.24        NaN   1.940000  NaN        NaN  21.400000
# 2020-01-08     12.11        NaN   2.010000  NaN        NaN  21.540001
# ...              ...        ...        ...  ...        ...        ...
# 2022-12-23      7.57  23.894825  20.980000  NaN  33.550362  16.650000
# 2022-12-27      7.53  23.825680  20.219999  NaN  33.442986  16.750000
# 2022-12-28      7.41  23.341656  19.900000  NaN  32.867058  16.700001
# 2022-12-29      7.61  23.726898  20.629999  NaN  33.560127  17.139999
# 2022-12-30      7.70  23.825680  20.100000  NaN  33.491798  17.440001
#
# ...
